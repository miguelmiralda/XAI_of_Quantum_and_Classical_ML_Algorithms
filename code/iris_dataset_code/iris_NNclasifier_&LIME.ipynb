# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.model_selection import GroupShuffleSplit


from sklearn.model_selection import train_test_split

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import callbacks
from tensorflow.keras.models import Sequential
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from lime.lime_text import LimeTextExplainer
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Path to your CSV file
file_path = r"C:\Users\migue\Downloads\9e7fdfb8189f0cdf5d73a494e4a6392a-aaecbd14aeaa468cd749528f291aa8a30c2ea09e\9e7fdfb8189f0cdf5d73a494e4a6392a-aaecbd14aeaa468cd749528f291aa8a30c2ea09e\iris_dataset.csv"

# Read the CSV file into a Pandas DataFrame
irisdf = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
print("Head of the DataFrame:")
print(irisdf)

# Display basic statistics of the DataFrame
print("\nBasic statistics:")
print(irisdf.describe())

# Check for missing values
print("\nMissing values in each column:")
print(irisdf.isnull().sum())

# Display DataFrame info to ensure it is ML-ready
print("\nDataFrame info:")
print(irisdf.info())
# Out:
# Head of the DataFrame:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#              target
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 5 columns]
#
# Basic statistics:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.054000           3.758667
# std             0.828066          0.433594           1.764420
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.198667
# std            0.763161
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000
#
# Missing values in each column:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64
#
# DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %%
X = irisdf.drop(columns='target')  # Features
y = irisdf['target']              # Target

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y) #This 2 steps make the non-numerical values of y numerical

# Ensure there are no missing values
print("Missing values in dataset:\n", irisdf.isnull().sum())

# Preprocessing pipeline
features_num = X.columns  # All features are numerical

preprocessor = make_column_transformer(
    (StandardScaler(), features_num),  # StandarScaler makes the data have mean 0 and variance 1 
    )

#X_to_split = X.preprocessor() 
# Split the dataset into train and validation sets
X_train, X_valid, y_train, y_valid = train_test_split(
    X, y_encoded, test_size=0.75, random_state=42, stratify=y_encoded
)



# Apply preprocessing to the training and validation sets
X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

# One-hot encode the target variables
y_train = to_categorical(y_train)
y_valid = to_categorical(y_valid)


input_shape = [X_train.shape[1]]
print("Input shape: {}".format(input_shape))

# Print the transformed data shapes and normalized feature example
print("X_train shape:", X_train.shape)
print("X_valid shape:", X_valid.shape)
print("First row of X_train after preprocessing:", X_train[0])
# Out:
# Missing values in dataset:
#  sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64
# Input shape: [4]
# X_train shape: (37, 4)
# X_valid shape: (113, 4)
# First row of X_train after preprocessing: [ 0.41159644 -1.74437157  0.41058885  0.48402956]

# %%
# Define the model
model = Sequential([
    Dense(128, activation='relu', input_shape=(4,)),  # First hidden layer
    Dropout(0.3),  # Dropout with 30% probability
    Dense(64, activation='relu'),  # Second hidden layer
    Dropout(0.2),  # Dropout with 20% probability
    Dense(3, activation='softmax')  # Output layer (3 classes)
])

# Compile the model

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Model summary
model.summary()
# Out:
# c:\Users\migue\miniconda\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 128)            │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,091 (35.51 KB)
#  Trainable params: 9,091 (35.51 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# why verbose 1???
history = model.fit(X_train, y_train, epochs=150, batch_size=10, validation_data=(X_valid, y_valid), verbose=1)
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 150ms/step - accuracy: 0.4363 - loss: 1.1098 - val_accuracy: 0.6726 - val_loss: 1.0269
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5961 - loss: 1.0244 - val_accuracy: 0.7876 - val_loss: 0.9426
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7677 - loss: 0.9240 - val_accuracy: 0.7965 - val_loss: 0.8648
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8901 - loss: 0.8601 - val_accuracy: 0.7965 - val_loss: 0.7896
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8251 - loss: 0.7793 - val_accuracy: 0.7965 - val_loss: 0.7180
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8635 - loss: 0.6585 - val_accuracy: 0.7876 - val_loss: 0.6533
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8518 - loss: 0.6265 - val_accuracy: 0.8053 - val_loss: 0.5970
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7851 - loss: 0.6041 - val_accuracy: 0.8053 - val_loss: 0.5494
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8318 - loss: 0.5451 - val_accuracy: 0.7876 - val_loss: 0.5098
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8485 - loss: 0.4509 - val_accuracy: 0.7965 - val_loss: 0.4779
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8318 - loss: 0.4606 - val_accuracy: 0.7965 - val_loss: 0.4513
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8868 - loss: 0.4157 - val_accuracy: 0.8053 - val_loss: 0.4294
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8993 - loss: 0.3770 - val_accuracy: 0.8053 - val_loss: 0.4108
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8826 - loss: 0.3470 - val_accuracy: 0.8142 - val_loss: 0.3939
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8226 - loss: 0.4315 - val_accuracy: 0.8142 - val_loss: 0.3800
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8626 - loss: 0.3307 - val_accuracy: 0.8142 - val_loss: 0.3685
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9101 - loss: 0.3417 - val_accuracy: 0.8142 - val_loss: 0.3578
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8701 - loss: 0.3152 - val_accuracy: 0.8230 - val_loss: 0.3491
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8501 - loss: 0.3179 - val_accuracy: 0.8142 - val_loss: 0.3405
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9268 - loss: 0.2451 - val_accuracy: 0.8142 - val_loss: 0.3314
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8968 - loss: 0.2353 - val_accuracy: 0.8142 - val_loss: 0.3244
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8759 - loss: 0.2661 - val_accuracy: 0.8319 - val_loss: 0.3166
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9101 - loss: 0.2341 - val_accuracy: 0.8319 - val_loss: 0.3105
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8968 - loss: 0.2274 - val_accuracy: 0.8407 - val_loss: 0.3038
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9076 - loss: 0.2156 - val_accuracy: 0.8407 - val_loss: 0.2987
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8668 - loss: 0.2504 - val_accuracy: 0.8584 - val_loss: 0.2931
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8968 - loss: 0.2448 - val_accuracy: 0.8673 - val_loss: 0.2878
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9076 - loss: 0.1762 - val_accuracy: 0.8584 - val_loss: 0.2814
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8993 - loss: 0.2168 - val_accuracy: 0.8496 - val_loss: 0.2751
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9242 - loss: 0.1851 - val_accuracy: 0.8584 - val_loss: 0.2688
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9142 - loss: 0.2545 - val_accuracy: 0.8584 - val_loss: 0.2629
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9617 - loss: 0.1950 - val_accuracy: 0.8673 - val_loss: 0.2594
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9717 - loss: 0.1695 - val_accuracy: 0.8584 - val_loss: 0.2594
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9892 - loss: 0.1488 - val_accuracy: 0.8584 - val_loss: 0.2602
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9268 - loss: 0.1695 - val_accuracy: 0.8584 - val_loss: 0.2662
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8626 - loss: 0.2108 - val_accuracy: 0.8673 - val_loss: 0.2596
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8576 - loss: 0.2112 - val_accuracy: 0.8673 - val_loss: 0.2474
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9650 - loss: 0.1317 - val_accuracy: 0.8850 - val_loss: 0.2387
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.1406 - val_accuracy: 0.8850 - val_loss: 0.2339
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9417 - loss: 0.1613 - val_accuracy: 0.8850 - val_loss: 0.2306
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9725 - loss: 0.1184 - val_accuracy: 0.8850 - val_loss: 0.2259
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9825 - loss: 0.1171 - val_accuracy: 0.9027 - val_loss: 0.2213
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9242 - loss: 0.1195 - val_accuracy: 0.9115 - val_loss: 0.2183
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9617 - loss: 0.1323 - val_accuracy: 0.9115 - val_loss: 0.2168
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9376 - loss: 0.1321 - val_accuracy: 0.8761 - val_loss: 0.2225
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.1492 - val_accuracy: 0.8761 - val_loss: 0.2312
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9417 - loss: 0.1226 - val_accuracy: 0.8761 - val_loss: 0.2421
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9617 - loss: 0.1278 - val_accuracy: 0.8761 - val_loss: 0.2586
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9892 - loss: 0.1100 - val_accuracy: 0.8761 - val_loss: 0.2549
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9525 - loss: 0.1095 - val_accuracy: 0.8761 - val_loss: 0.2356
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9892 - loss: 0.0778 - val_accuracy: 0.8761 - val_loss: 0.2268
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9525 - loss: 0.1719 - val_accuracy: 0.8761 - val_loss: 0.2280
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9892 - loss: 0.0979 - val_accuracy: 0.8850 - val_loss: 0.2195
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9550 - loss: 0.0913 - val_accuracy: 0.8938 - val_loss: 0.2027
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9525 - loss: 0.0760 - val_accuracy: 0.9027 - val_loss: 0.1950
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9825 - loss: 0.0736 - val_accuracy: 0.9027 - val_loss: 0.1914
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9525 - loss: 0.1497 - val_accuracy: 0.9027 - val_loss: 0.1879
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0893 - val_accuracy: 0.9027 - val_loss: 0.1880
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9142 - loss: 0.1434 - val_accuracy: 0.9115 - val_loss: 0.1864
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9542 - loss: 0.1088 - val_accuracy: 0.9027 - val_loss: 0.1903
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9417 - loss: 0.1135 - val_accuracy: 0.9027 - val_loss: 0.1880
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9725 - loss: 0.0993 - val_accuracy: 0.8938 - val_loss: 0.2006
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9892 - loss: 0.0497 - val_accuracy: 0.8850 - val_loss: 0.2080
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9650 - loss: 0.0919 - val_accuracy: 0.8850 - val_loss: 0.2095
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0844 - val_accuracy: 0.8850 - val_loss: 0.2134
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0698 - val_accuracy: 0.8850 - val_loss: 0.2090
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9350 - loss: 0.1135 - val_accuracy: 0.8850 - val_loss: 0.2140
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9550 - loss: 0.0706 - val_accuracy: 0.8850 - val_loss: 0.2015
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9825 - loss: 0.0847 - val_accuracy: 0.8938 - val_loss: 0.1910
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9525 - loss: 0.0731 - val_accuracy: 0.9115 - val_loss: 0.1815
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9717 - loss: 0.0873 - val_accuracy: 0.9115 - val_loss: 0.1818
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0563 - val_accuracy: 0.9115 - val_loss: 0.1726
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9525 - loss: 0.1346 - val_accuracy: 0.9292 - val_loss: 0.1699
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9717 - loss: 0.0551 - val_accuracy: 0.9292 - val_loss: 0.1696
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9650 - loss: 0.0651 - val_accuracy: 0.9115 - val_loss: 0.1720
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9825 - loss: 0.0845 - val_accuracy: 0.9115 - val_loss: 0.1875
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0419 - val_accuracy: 0.8938 - val_loss: 0.1976
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9892 - loss: 0.0567 - val_accuracy: 0.8938 - val_loss: 0.2006
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9450 - loss: 0.0885 - val_accuracy: 0.9115 - val_loss: 0.1930
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9825 - loss: 0.0665 - val_accuracy: 0.9115 - val_loss: 0.1858
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0447 - val_accuracy: 0.9204 - val_loss: 0.1776
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0660 - val_accuracy: 0.9292 - val_loss: 0.1686
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0326 - val_accuracy: 0.9292 - val_loss: 0.1709
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9525 - loss: 0.1116 - val_accuracy: 0.9292 - val_loss: 0.1791
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9825 - loss: 0.0618 - val_accuracy: 0.9292 - val_loss: 0.1863
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9525 - loss: 0.0862 - val_accuracy: 0.9292 - val_loss: 0.1866
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9525 - loss: 0.0797 - val_accuracy: 0.9292 - val_loss: 0.1780
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9650 - loss: 0.0867 - val_accuracy: 0.9292 - val_loss: 0.1748
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9525 - loss: 0.0871 - val_accuracy: 0.9292 - val_loss: 0.1677
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0315 - val_accuracy: 0.9292 - val_loss: 0.1690
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9725 - loss: 0.0655 - val_accuracy: 0.9292 - val_loss: 0.1783
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9417 - loss: 0.0757 - val_accuracy: 0.9292 - val_loss: 0.1947
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9825 - loss: 0.0400 - val_accuracy: 0.9204 - val_loss: 0.1939
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0516 - val_accuracy: 0.9292 - val_loss: 0.1828
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9825 - loss: 0.0673 - val_accuracy: 0.9292 - val_loss: 0.1863
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9892 - loss: 0.0667 - val_accuracy: 0.9115 - val_loss: 0.2055
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9892 - loss: 0.0532 - val_accuracy: 0.8938 - val_loss: 0.2194
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0247 - val_accuracy: 0.8938 - val_loss: 0.2143
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0233 - val_accuracy: 0.9204 - val_loss: 0.2024
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9417 - loss: 0.1218 - val_accuracy: 0.9292 - val_loss: 0.1963

# %%
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()))
correct = 0
for i in range(len(y_valid)):
    if np.argmax(y_valid[i]) == np.argmax(model.predict(X_valid[i].reshape(1, -1))):
        correct += 1
percent_correct = correct * 100 / len(y_valid)
print('The percentage of correct assignments for the neural network is', percent_correct, '%')
# Out:
# Minimum Validation Loss: 0.1677
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# The percentage of correct assignments for the neural network is 92.92035398230088 %

# %%
import lime
import lime.lime_tabular

# Use the actual feature names from iris dataset
feature_names = ["sepal length (cm)", "sepal width (cm)",  "petal length (cm)", "petal width (cm)"]  # Get only the first 4 feature names
origional_explainer = lime.lime_tabular.LimeTabularExplainer(
	X_valid, 
	feature_names=feature_names,
	class_names=["Iris-setosa","Iris-virginica", "Iris-versicolor"],
	discretize_continuous=0
)

# Create explanation for a single instance
origional_exp = origional_explainer.explain_instance(
	X_valid[0], 
	lambda x: model.predict(x), 
	num_features=4, 
	top_labels=3
)
print(origional_exp.as_list())
# Display the explanation
#Feature contributions QLIME \(\pi\)  (The numbers refer to the features in the following order: sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)):[0.10366189  0.01569134  0.98544151 -0.0016377 ]
#]
#Feature contributions LIME: [('petal width (cm)', -0.267829144579525), ('sepal length (cm)', 0.14283610989391415), ('petal length (cm)', -0.14165876551347437), ('sepal width (cm)', -0.11564151926700811)]

#origional_exp.show_in_notebook(show_table=True, show_all=True)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# [('petal width (cm)', -0.267829144579525), ('sepal length (cm)', 0.14283610989391415), ('petal length (cm)', -0.14165876551347437), ('sepal width (cm)', -0.11564151926700811)]

# %%
import numpy as np
import pennylane as qml
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Load the iris dataset
iris = load_iris()
X = iris.data  # Feature data
y = iris.target  # Labels

iris.df = pd.DataFrame(X, columns=iris.feature_names)
print(iris.df.head())
# Convert features to binary values based on the mean
mean_values = np.mean(X, axis=0)
binary_vectorized_data = (X > mean_values).astype(int)

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(binary_vectorized_data, y, test_size=0.2, random_state=42)

# Define a simple neural network classifier
# def build_nn_classifier(input_dim):
#     model = keras.Sequential([
#         layers.Dense(10, activation='relu', input_shape=(input_dim,)),
#         layers.Dense(10, activation='relu'),
#         layers.Dense(3, activation='softmax')  # 3 output classes
#     ])
#     model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#     return model

# Build and train the neural network classifier
nn_classifier = model # build_nn_classifier(X_train.shape[1])
#nn_classifier.fit(X_train, y_train, epochs=100, batch_size=10, verbose=1)

# Quantum function to encode and flip bits
def encode_and_flip(features, flip_index=None, shots=None):
    dev = qml.device("default.qubit", wires=len(features), shots=shots)
    
    @qml.qnode(dev)
    def circuit():
        for i, f in enumerate(features):
            if i == flip_index: # and f == 1:   ;;  This line is the original code commented out
                # 1->0 => RY(0),
                #theta = 0
                theta = f * (np.pi / 2)            
                qml.PauliX(wires=i)
            else:
                theta = f * (np.pi / 2)
 
            qml.RY(theta, wires=i)
            
        return qml.probs(wires=range(len(features)))
    
    return circuit()

# Measure and map quantum state to classical bitstring
def measure_and_map_to_classical(features, flip_index=None, shots=None):
    probs = encode_and_flip(features, flip_index, shots=shots)
    
    measured_state = np.random.choice(len(probs), p=probs)
    bin_string = f"{measured_state:0{len(features)}b}"
    print("jnndjd ", probs)
    return np.array([int(bit) for bit in bin_string])

# Explain function using Q-LIME
def explain(vector, model, full_superposition=True, shots=None):
    original_pred = model.predict(vector.reshape(1, -1))[0]
    contributions = np.zeros(len(vector))
    
    for i in range(len(vector)):
        if vector[i] == 1 or full_superposition:
            new_vec = measure_and_map_to_classical(vector, flip_index=i,  shots=shots)
            new_pred = model.predict(new_vec.reshape(1, -1))[0]
            contributions[i] = original_pred[np.argmax(original_pred)] - new_pred[np.argmax(original_pred)]
    
    return contributions

# Example usage
sample_vector = X_test[0] 

contributions = explain(sample_vector, nn_classifier, shots=100)
print("Feature contributions:", contributions)
print(model.predict(sample_vector.reshape(1, -1)))
print("Sample measured ", sample_vector) # Pick a sample
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# jnndjd  [0.08 0.13 0.15 0.16 0.   0.   0.   0.   0.11 0.13 0.12 0.12 0.   0.
#  0.   0.  ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# jnndjd  [0.   0.   0.   0.   0.12 0.09 0.1  0.12 0.   0.   0.   0.   0.09 0.22
#  0.07 0.19]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# jnndjd  [0.08 0.14 0.17 0.11 0.   0.   0.   0.   0.12 0.1  0.1  0.18 0.   0.
#  0.   0.  ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# jnndjd  [0.11 0.16 0.12 0.12 0.   0.   0.   0.   0.12 0.11 0.18 0.08 0.   0.
#  0.   0.  ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Feature contributions: [0.67243016 0.91322535 0.10366189 0.99410683]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[1.24209555e-05 2.72474275e-03 9.97262836e-01]]
# Sample measured  [1 0 1 1]

# %%
correct = 0

for i in range(len(y_valid)):
    if np.argmax(y_valid[i]) == np.argmax(model.predict(X_valid[i].reshape(1, -1))):
        correct += 1
percent_correct = correct * 100 / len(y_valid)
print('The percentage of correct assignments for the neural network is', percent_correct, '%')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# The percentage of correct assignments for the neural network is 92.92035398230088 %
